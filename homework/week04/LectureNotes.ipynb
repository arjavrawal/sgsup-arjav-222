# %% [markdown]
# ### Data Structures
# #### 9/15/2025

# %%
# create a list
my_list = [1, 2, 3, 4, 5.5, -1.2]

# %%
print(my_list)
# Out:
# [1, 2, 3, 4, 5.5, -1.2]

# %%
len(my_list)
# Out:
# 6

# %%
my_list[0]
# Out:
# 1

# %%
my_list[1]
# Out:
# 2

# %%
my_list[-1]
# Out:
# -1.2

# %%
my_list[1:-2]
# Out:
# [2, 3, 4]

# %%
my_list2 = my_list[1:-2]

# %%
my_list2.append("पाँच")

# %%
print(my_list2)
# Out:
# [2, 3, 4, 'a new value', 'पाँच', 'पाँच']

# %%
sum(my_list)
# Out:
# 14.3

# %%
sum(my_list2[0:3])
# Out:
# 9

# %%
my_list2.pop(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 my_list2.pop(1)
#
# IndexError: pop from empty list

# %%
my_list2 = my_list[1:-2]

# %%
my_list2.append("a new value")

# %%
my_list2.pop(-1)
# Out:
# 'a new value'

# %%
dict_1 = {"key1": "value1", "key2": "value2", "key3": "value3"}

# %%
dict_1.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
dict_1.values()
# Out:
# dict_values(['value1', 'value2', 'value3'])

# %%
dict_1['key1']
# Out:
# 'value1'

# %%
dict_1['key1'] = 'updates!'
dict_1['key1']
# Out:
# 'updates!'

# %%
dict_1['key3']
# Out:
# 'value3'

# %%
dict_1['key2']
# Out:
# 'value2'

# %%
dict_1['a new key'] = 'a new value'

# %%
dict_1['a list'] = my_list2

# %%
# create a second dictionary
dict_2 = {'key3': 'newvalue3', 'key4': 'value4', 'key5': 'value5'}

# %%
print(dict_1, dict_2)
# Out:
# {'key1': 'updates!', 'key2': 'value2', 'key3': 'value3', 'a new key': 'a new value', 'a list': [2, 3, 4]} {'key3': 'newvalue3', 'key4': 'value4', 'key5': 'value5'}

# %%
dict_1['key1']
# Out:
# 'updates!'

# %%
dict_1
# Out:
# {'key1': 'updates!',
#  'key2': 'value2',
#  'key3': 'value3',
#  'a new key': 'a new value',
#  'a list': [2, 3, 4]}

# %%
# difference between lists and dictionaries - dictionaries have keys that map to values, lists are ordered collections of values

# %%
# combine two dictionaries
dict_1.update(dict_2)

# %%
dict_1
# Out:
# {'key1': 'updates!',
#  'key2': 'value2',
#  'key3': 'newvalue3',
#  'a new key': 'a new value',
#  'a list': [2, 3, 4],
#  'key4': 'value4',
#  'key5': 'value5'}

# %%
import json

# %%
with open('data.geojson') as f:
    data = json.load(f)

# the file is stored in a variable called data, then we find the type

# %%
type(data)

# this is checking the type of the variable
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['type', 'features', 'crs'])

# %%
data['type']

# this checks the value of the key called type as opposed to the type of the variable
# Out:
# 'FeatureCollection'

# %%
data['crs']
# Out:
# {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}}

# %%
data['features']
# Out:
# [{'type': 'Feature',
#   'geometry': {'type': 'Point', 'coordinates': [-122.42710769, 37.75976521]},
#   'properties': {'status_description': 'Closed',
#    'bos_2012': '8.00000',
#    'source': 'Mobile/Open311',
#    'updated_datetime': '2023-01-01T01:58:00.000',
#    'police_district': 'MISSION',
#    'agency_responsible': 'RPD NSA Queue',
#    'media_url': None,
#    'neighborhoods_sffind_boundaries': 'Mission Dolores',
#    'requested_datetime': '2023-01-01T00:11:54.000',
#    'service_request_id': '16240855',
#    'service_name': 'Noise Report',
#    'data_loaded_at': '2024-02-20T15:21:23.000',
#    'long': '-122.427107691765',
#    'status_notes': 'Comment Noted',
#    'point_geom': {'type': 'Point',
#     'coordinates': [-122.427107692, 37.759765211]},
#    'address': 'Mission Dolores Park, , SAN FRANCISCO, CA, 94114',
#    'street': 'Mission Dolores Park',
#    'supervisor_district': '8.00000',
#    'service_details': 'Other',
#    'service_subtype': 'Noise Issue',
# ...

# %%
type(data['features'])

# this is checking the type of the key in the datafile
# Out:
# list

# %%
len(data['features'])
# Out:
# 10000

# %% [markdown]
# # always remember, if you want to pull an element from a list, start with 0

# %%
type(data['features'][0])
# what type of data is in the first element of the features key, which has a list as its data type
# Out:
# dict

# %%
first_feature = data['features'][0]

# %%
first_feature.keys()
# Out:
# dict_keys(['type', 'geometry', 'properties'])

# %%
first_feature['type']
# Out:
# 'Feature'

# %%
first_feature['geometry']
# Out:
# {'type': 'Point', 'coordinates': [-122.42710769, 37.75976521]}

# %%
first_feature['properties']
# Out:
# {'status_description': 'Closed',
#  'bos_2012': '8.00000',
#  'source': 'Mobile/Open311',
#  'updated_datetime': '2023-01-01T01:58:00.000',
#  'police_district': 'MISSION',
#  'agency_responsible': 'RPD NSA Queue',
#  'media_url': None,
#  'neighborhoods_sffind_boundaries': 'Mission Dolores',
#  'requested_datetime': '2023-01-01T00:11:54.000',
#  'service_request_id': '16240855',
#  'service_name': 'Noise Report',
#  'data_loaded_at': '2024-02-20T15:21:23.000',
#  'long': '-122.427107691765',
#  'status_notes': 'Comment Noted',
#  'point_geom': {'type': 'Point',
#   'coordinates': [-122.427107692, 37.759765211]},
#  'address': 'Mission Dolores Park, , SAN FRANCISCO, CA, 94114',
#  'street': 'Mission Dolores Park',
#  'supervisor_district': '8.00000',
#  'service_details': 'Other',
#  'service_subtype': 'Noise Issue',
#  'data_as_of': '2024-02-20T10:35:55.000',
#  'closed_date': '2023-01-01T01:58:00.000',
#  'lat': '37.759765210592'}
