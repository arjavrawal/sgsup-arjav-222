# %% [markdown]
# # Bonus Exercise: Republican Votes 2020 by Precinct (2 pts)
#
# You will work with a large plain‑text file containing the certified vote totals for every candidate in Maricopa County's 2020 general election. The file is hosted in a public GitHub repository. Instead of downloading it manually, you will write functions that read the file directly from its URL using Python.
#
# **File URL**: `https://raw.githubusercontent.com/schmeeckle/stuff/main/11-03-2020-2b%20Final%20SOV%20and%20Official%20Canvass%20Report%20NOV2020.txt`
#
# Each line of the file contains a precinct name, a candidate name, and the number of votes they received. Candidate names and precinct names may appear in uppercase or lowercase, so be sure to compare them without case sensitivity.
#
# ### Task 1: precinct_votes(candidate, precinct)
#
# Implement a function `precinct_votes(candidate, precinct)` that takes a candidate name (string) and a precinct name (string) and returns the integer number of votes that candidate received in that precinct.
#
# To do this:
#
# 1. Use `urllib.request` to fetch the file contents into a list of lines.
# 2. Iterate through the lines, decoding each line from binary to UTF‑8 using `.decode('utf8')`.
# 3. If the line contains both the candidate name and the precinct name (case‑insensitive), extract the vote total (an integer) from that line.
# 4. Return the vote total.
#
# Hint: This is a tab-delimited file rather than the common comma-delimited file. So one way to find the votes is to find the number of tabs just before the number of votes. There are several other ways of doing this with what you have already learned. However, the simplest and most common way to do this is to use the split('\t') string method. This will split the line between each tab and create a list. Then you only have to find the correct element in the list. I know lists are covered next chapter. One strategy is to start the challenge now, but finish this challenge when you know enough about lists. Remember, there is no penalty for a late challenge.

# %%
import urllib.request
import ssl

def precinct_votes(candidate, precinct):
    url = "https://raw.githubusercontent.com/schmeeckle/stuff/main/11-03-2020-2b%20Final%20SOV%20and%20Official%20Canvass%20Report%20NOV2020.txt"
    context = ssl._create_unverified_context()
    # YOUR CODE HERE
    return votes

# %%
# Tests for precinct_votes
assert precinct_votes('biggs','Colonia') == 2510
assert precinct_votes('trump', 'Citrus') == 754
assert precinct_votes('MESNARD', 'GERONIMO') == 631
print("If no assertion errors appear, your function may be correct for Task 1!")

# %% [markdown]
# ### Task 2: total_votes(candidate)
#
# Write a second function `total_votes(candidate)` that returns the total number of votes a candidate received across **all** Maricopa County precincts.
#
# This function should:
#
# 1. Read the same file as before.
# 2. Sum the vote totals for lines that contain the candidate's name (case‑insensitive).
# 3. Return the resulting sum as an integer.

# %%
import urllib.request
import ssl

def total_votes(candidate):
    url = "https://raw.githubusercontent.com/schmeeckle/stuff/main/11-03-2020-2b%20Final%20SOV%20and%20Official%20Canvass%20Report%20NOV2020.txt"
    context = ssl._create_unverified_context()
    # YOUR CODE HERE
    return votes

# %%
# Tests for total_votes
assert total_votes('trump') == 995665
assert total_votes('BiGGs') == 262414
print("If no assertion errors appear, your function may be correct for Task 2!")

# %% [markdown]
# ## Deliverable
#
# - Complete the `precinct_votes` and `total_votes` functions.
# - Run all cells to ensure the assertions pass.
# - Submit your notebook (.ipynb) on Canvas.
#
# **Rubric (2 pts):**
#
# | Component | Points |
# |---|---|
# | `precinct_votes` correctly returns vote totals for given candidate/precinct combinations | 1 |
# | `total_votes` correctly sums votes across precincts and notebook runs without errors | 1 |
