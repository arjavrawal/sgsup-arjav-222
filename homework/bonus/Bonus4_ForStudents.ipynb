# %% [markdown]
# # Bonus Exercise: Early Voting Returns by Precinct (2 pts)
#
# During the early voting period of a general election, the Maricopa County Recorder updates a public web map showing how many ballots have been returned in each voting precinct. The data are served as a feature layer via ArcGIS Online. In this exercise you will write Python code to query the layer and extract useful information.
#
# Run the cell below to query the layer and convert the JSON response into a Python dictionary named `returns`.

# %%
import urllib.request
import json
import ssl
context = ssl._create_unverified_context()
url = "https://services.arcgis.com/ykpntM6e3tHvzKRJ/arcgis/rest/services/Maricopa_County_Early_Voting_Return_Statistics_(Republican)/FeatureServer/0/query?where=1%3D1&objectIds=&time=&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&resultType=none&distance=0.0&units=esriSRUnit_Meter&relationParam=&returnGeodetic=false&outFields=*&returnGeometry=false&returnCentroid=false&featureEncoding=esriDefault&multipatchOption=xyFootprint&maxAllowableOffset=&geometryPrecision=&outSR=&defaultSR=&datumTransformation=&applyVCSProjection=false&returnIdsOnly=false&returnUniqueIdsOnly=false&returnCountOnly=false&returnExtentOnly=false&returnQueryGeometry=false&returnDistinctValues=false&cacheHint=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&having=&resultOffset=&resultRecordCount=&returnZ=false&returnM=false&returnExceededLimit=false"
req = urllib.request.Request(url, headers={'User-Agent':'Mozilla/5.0'})
with urllib.request.urlopen(req, context=context) as f:
    data = json.loads(f.read().decode('utf-8'))
returns = data['features']
type(returns)

# %% [markdown]
# ## Task: Extract precinct data
#
# The `returns` list is made up of dictionaries with an `attributes` key. Each attribute dictionary includes:
#
# - `'BdName'`: the precinct name (string)
# - `'Returns'`: the number of ballots returned (integer)
# - `'PercentReturned'`: the percent of ballots returned (float)
#
# Write code to loop through `returns` and populate three lists:
#
# 1. `precinct_name` (strings)
# 2. `returned_ballots` (integers)
# 3. `percent_returned` (floats)
#
# Each list should contain an entry for every precinct in the dataset.
#
# Your assignment here is to extract 'BdName','Returns',and 'PercentReturned' that are all in the 'attributes' dictionary. You should put these in three lists precinct_name, returned_ballots, and percent_returned that contain data from each of the voting precincts. percent_returned should be a list of floating point numbers; returned_ballots should be a list of integers; and precinct_name should be a list of strings.

# %%
precinct_name = []
returned_ballots = []
percent_returned = []
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Example structure shown below (do not modify).
assert precinct_name == precinct_name_answer
assert returned_ballots == returned_ballots_answer
assert percent_returned == percent_returned_answer
print("If your code runs without errors and populates the lists, you should be in good shape!")

# %% [markdown]
# ## Deliverable
#
# - Populate the three lists (`precinct_name`, `returned_ballots`, `percent_returned`) using the `returns` data.
# - Run all cells to confirm your lists contain data for every precinct.
# - Submit your notebook (.ipynb) on Canvas.
#
# **Rubric (2 pts):**
#
# | Component | Points |
# |---|---|
# | Lists correctly populated with names, returned ballots, and percentages | 1 |
# | Code runs without errors and lists have correct data types (str, int, float) | 1 |
