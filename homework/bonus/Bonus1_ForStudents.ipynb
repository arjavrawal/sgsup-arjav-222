# %% [markdown]
# # Bonus Exercise: School Transmission Levels (2 pts)
#
# In this exercise, you'll write a function to classify school transmission levels based on community COVID‑19 indicators. The Maricopa County GIS team publishes a map of COVID‑19 transmission levels for school districts. For each district, they compute two key indicators:
#
# - **Percent Positivity** of COVID tests over the last 14 days.
# - **New cases per 100,000 people** in the last 7 days.
#
# The CDC defines the community transmission level as follows:
#
# - **Low**: Percent positivity <5% and new cases per 100k <10.
# - **Moderate**: Percent positivity 5.0–7.9% *or* new cases per 100k between 10 and 49.
# - **Substantial**: Percent positivity 8.0–9.9% *or* new cases per 100k between 50 and 99.
# - **High**: Percent positivity ≥10% *or* new cases per 100k ≥100.
#
# When the two indicators point to different levels, choose the higher (more severe) level.
#
# Write a function `school_transmission_level(positivity, new_cases)` that takes two numbers (percent positivity and new cases per 100k) and returns a string `'low'`, `'moderate'`, `'substantial'`, or `'high'`. Use the thresholds above.

# %%
def school_transmission_level(positivity, new_cases):
    '''
    Implement your function here.

    Parameters:
    - positivity (float): test positivity percentage.
    - new_cases (float): new cases per 100,000 people.

    Returns:
    - str: one of 'low', 'moderate', 'substantial', 'high'.
    '''
    # YOUR CODE HERE
    return

# %%
# tests
assert school_transmission_level(10.0, 1) == 'high'
assert school_transmission_level(7.2, 19) == 'moderate'
assert school_transmission_level(6.3, 99) == 'substantial'
assert school_transmission_level(4.2, 5) == 'low'
print("If no assertion errors appear, your function is correct!")

# %% [markdown]
# ## Deliverable
#
# - Implement the `school_transmission_level` function above.
# - Run all cells to ensure the assertions pass.
# - Submit your notebook (.ipynb) containing your function implementation on Canvas.
#
# **Rubric (2 pts):**
#
# | Component | Points |
# |---|---|
# | Correctly implements the classification logic for all threshold combinations | 1 |
# | Notebook runs without errors and follows good coding style (clear variable names, comments) | 1 |
