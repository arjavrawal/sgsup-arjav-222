# %%
# Lecture 8: Working with Files and REST API

# Tokyo, LA, London, Sydney, Paris. write method is used to string to the file. r mode reads the file, w mode opens the file, creates if it doesn't exist, and overwrites if the file exists. a mode appends, x mode if overwriting isn't allowed.

sample_data = """35.6895,139.6917
34.0522,-118.2437
51.5074,-0.1278
-33.8688,151.2093
48.8566,2.3522"""
output_file = "coordinates.txt"
try:
    with open(output_file, "w") as file:
        file.write(sample_data)
    print(f"Sample file '{output_file}' has been created successfully.")
except Exception as e:
    print(f"An error occurred while creating the file: {e}")
# Out:
# Sample file 'coordinates.txt' has been created successfully.

# %%
# practical example to read and write

# example of reading coordinates from a file and writing to another file
input_file = "coordinates.txt"
output_file = "output_coordinates.txt"

try:
    # Step 1 - read the coordinates data from our input file
    with open(input_file, "r") as infile:
        # readlines() returns a list where each element is a line from the file
        # each line still includes the newline character (\n) at the end
        coordinates = infile.readlines()
    # Step 2 - process the data and write it to a new file with better formatting
    with open(output_file, "w") as outfile:
        for line in coordinates:
            # strip() removes whitespace (\n) from both ends of the string
            # split(",") breaks the line into parts wherever it finds a comma
            lat, lon = line.strip().split(",")
            # Write the formatted data to our output file
            # The \n adds a newline character so each coordinate is on its own line
            outfile.write(f"Latitude: {lat}, Longitude: {lon}\n")
    print(f"Coordinates have been written to {output_file}")
except FileNotFoundError:
    print(f"Error: The file {input_file} was not found.")
    print("Make sure you ran the previous code cell to create the coordinates.txt file.")
# Out:
# Coordinates have been written to output_coordinates.txt

# %%
# Exception handling - if files are corrupted, missing, networks down, etc.

# try - code that might cause error
# except - runs if error occurs
# finally - optional, code block that runs regardless

# Example:

def parse_coordinates(line):
    """

    Parse a line of text into latitude and longitude coordinates.
    Args:
    line (str): A string containing coordinates in the format "lat,lon"
    Returns:
    tuple: (latitude, longitude) as floats, or None if parsing fails
    """
    try:
        # Attempt to split the line and convert to numbers
        lat, lon = line.strip().split(",")
        lat = float(lat) # ValueError if lat isn't a valid number
        lon = float(lon) # ValueError if lon isn't a valid number
        return lat, lon
    except ValueError as e:
        print(f"Data format error: {e}. Could not parse line: '{line.strip()}'\n")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}\n")
        return None

# %%
test_lines = [
    "35.6895,139.6917",
    "invalid data",
    "45.0,-119.0",
    "45.0,not_a_number",
    "only_one_value",
]
print("Testing coordinate parsing:")
for line in test_lines:
    coordinates = parse_coordinates(line)
    if coordinates:
        print(f"Successfully parsed: {coordinates}\n")
    else:
        print(f"Failed to parse: '{line}'\n")
# Out:
# Testing coordinate parsing:
# Successfully parsed: (35.6895, 139.6917)
#
# Data format error: not enough values to unpack (expected 2, got 1). Could not parse line: 'invalid data'
#
# Failed to parse: 'invalid data'
#
# Successfully parsed: (45.0, -119.0)
#
# Data format error: could not convert string to float: 'not_a_number'. Could not parse line: '45.0,not_a_number'
#
# Failed to parse: '45.0,not_a_number'
#
# Data format error: not enough values to unpack (expected 2, got 1). Could not parse line: 'only_one_value'
#
# Failed to parse: 'only_one_value'

# %%
# combining file handling with exception handling.

# graceful degradation - should handle as much good data as possible, skip problematic data with appropriate warnings, and continue processing

def process_geospatial_file(input_file):
    processed_count = 0
    error_count = 0
    try:
        print(f"Starting to process file: {input_file}")
        with open(input_file,"r") as infile:
            for line_number, line in enumerate(infile, 1):
                if not line.strip():
                    continue
                coordinates = parse_coordinates(line)
                if coordinates:
                    lat, lon = coordinates
                    print(
                        f"Line {line_number}: Processed coordinates ({lat:.4f},{lon:.4f})"
                    )
                    processed_count += 1
                else:
                    print(f"Line {line_number}: Skipped due to parsing error")
                    error_count += 1
    except FileNotFoundError:
        print(f"Error: The file '{input_file}' was not found.")
        print("Please check the file path and make sure the file exists.")
        return
    except PermissionError:
        print(f"Error: Permission denied when trying to read '{input_file}'.")
        print("Please check if you have read permissions for this file.")
    except Exception as e:
        print(f"An unexpected error occurred while processing the file: {e}")
        return
    finally:
        print(f"\n--- Processing Summary ---")
        print(f"Successfully processed: {processed_count} coordinates")
        print(f"Errors encountered: {error_count} lines")
        print(f"Finished processing {input_file}")

process_geospatial_file("coordinates.txt")
# Out:
# Starting to process file: coordinates.txt
# Line 1: Processed coordinates (35.6895,139.6917)
# Line 2: Processed coordinates (34.0522,-118.2437)
# Line 3: Processed coordinates (51.5074,-0.1278)
# Line 4: Processed coordinates (-33.8688,151.2093)
# Line 5: Processed coordinates (48.8566,2.3522)
#
# --- Processing Summary ---
# Successfully processed: 5 coordinates
# Errors encountered: 0 lines
# Finished processing coordinates.txt

# %%
csv_data = """City,Latitude,Longitude
Tokyo,35.6895,139.6917
Los Angeles,34.0522,-118.2437
London,51.5074,-0.1278
Sydney,-33.8688,151.2093
Paris,48.8566,2.3522"""
output_file = "coordinates.csv"
try:
    with open(output_file, "w") as file:
        file.write(sample_data)
    print(f"Sample file '{output_file}' has been created successfully.")
except Exception as e:
    print(f"An error occurred while creating the file: {e}")

# %%
import requests
from arcgis.gis import GIS
from arcgis.features import GeoAccessor
import pandas as pd
import json

# %%
# set up ArcGIS Online credentials
gis = GIS("home")

# display my user info
gis.users.me
# Out:
# <User username:adrawal_asu>

# %%
url = "https://phl.carto.com/api/v2/sql"
params = {
    "q": "SELECT * FROM public_cases_fc WHERE requested_datetime >= current_date - 7 AND subject = 'Illegal Dumping'",
}

response = requests.get(url, params=params)
data = response.json()

# %%
data
# Out:
# {'rows': [{'cartodb_id': 69506,
#    'the_geom': '0101000020E61000001DB39EBA88CE52C0FA9C3A94AAF34340',
#    'the_geom_webmercator': '0101000020110F000010A9267CF8F15FC10C181A753B825241',
#    'objectid': 5470544,
#    'service_request_id': 18426976,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:55:29Z',
#    'updated_datetime': '2025-10-14T23:00:35Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '7000 HOLSTEIN AVE',
#    'zipcode': '19153',
#    'media_url': None,
#    'lat': 39.90364316,
#    'lon': -75.22709527},
#   {'cartodb_id': 82315,
#    'the_geom': '0101000020E61000007A162939CCCE52C0FD039B2963F44340',
#    'the_geom_webmercator': '0101000020110F0000EFAB7D216BF25FC1BA4182D207835241',
#    'objectid': 5470548,
#    'service_request_id': 18426985,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:56:02Z',
#    'updated_datetime': '2025-10-14T23:01:09Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '7100   Lindbergh Blvd.',
#    'zipcode': None,
#    'media_url': None,
#    'lat': 39.9092762,
#    'lon': -75.2312148},
#   {'cartodb_id': 82832,
#    'the_geom': '0101000020E6100000F1D526FF87CE52C0359D8B29D2FD4340',
#    'the_geom_webmercator': '0101000020110F000070A6B73DF7F15FC138688E2E7B8D5241',
#    'objectid': 5470549,
#    'service_request_id': 18426987,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:56:07Z',
#    'updated_datetime': '2025-10-14T23:01:13Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '5300   Parkside Ave',
#    'zipcode': None,
#    'media_url': None,
#    'lat': 39.98297614,
#    'lon': -75.22705058},
#   {'cartodb_id': 109105,
#    'the_geom': '0101000020E6100000AF87B74A0AC852C098DA45F139FC4340',
#    'the_geom_webmercator': '0101000020110F000093DC10ABF0E65FC18187E5BFB68B5241',
#    'objectid': 5470559,
#    'service_request_id': 18427020,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:57:50Z',
#    'updated_datetime': '2025-10-14T23:02:56Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1032 E BERKS ST',
#    'zipcode': '19125',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_c142dcf03bb39e78463697308969eacd',
#    'lat': 39.97051826,
#    'lon': -75.12562817},
#   {'cartodb_id': 89750,
#    'the_geom': '0101000020E6100000B36BE1F7E4CD52C0F6BD325DF1F74340',
#    'the_geom_webmercator': '0101000020110F0000A2D92852E2F05FC1EB5054D0F7865241',
#    'objectid': 5470550,
#    'service_request_id': 18426989,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:56:12Z',
#    'updated_datetime': '2025-10-14T23:01:19Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1715 S 53RD ST',
#    'zipcode': '19143',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_ed69da7f6813df05095d278bb3600370',
#    'lat': 39.93705335,
#    'lon': -75.21710011},
#   {'cartodb_id': 134944,
#    'the_geom': '0101000020E6100000B8613C75FBC752C0857B0ED2EEFD4340',
#    'the_geom_webmercator': '0101000020110F00000384A978D7E65FC1B6FA71F29A8D5241',
#    'objectid': 5462448,
#    'service_request_id': 18270373,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:06:19Z',
#    'updated_datetime': '2025-10-10T11:25:46Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T11:25:02Z',
#    'address': '2537 FRANKFORD AVE',
#    'zipcode': '19125',
#    'media_url': None,
#    'lat': 39.98385072,
#    'lon': -75.12472278},
#   {'cartodb_id': 116735,
#    'the_geom': '0101000020E6100000980B18340BC952C0497A6DE53BFD4340',
#    'the_geom_webmercator': '0101000020110F00006F93F80EA5E85FC1759EACA1D48C5241',
#    'objectid': 5470571,
#    'service_request_id': 18427047,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:59:12Z',
#    'updated_datetime': '2025-10-14T23:04:17Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1800-18 N 4TH ST',
#    'zipcode': '19122',
#    'media_url': None,
#    'lat': 39.97839039,
#    'lon': -75.14130881},
#   {'cartodb_id': 118707,
#    'the_geom': '0101000020E6100000BD7A237549CA52C0D663CCBED2F44340',
#    'the_geom_webmercator': '0101000020110F0000E1C822A5C1EA5FC15D060D5F83835241',
#    'objectid': 5462442,
#    'service_request_id': 18270367,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:05:45Z',
#    'updated_datetime': '2025-10-10T10:24:54Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T10:24:14Z',
#    'address': '702 BIGLER ST',
#    'zipcode': '19148',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_1f119d145503a632df8bfff39da6423a',
#    'lat': 39.91268144,
#    'lon': -75.16073349},
#   {'cartodb_id': 112545,
#    'the_geom': '0101000020E61000007E17DC22DEC952C089545AE103F74340',
#    'the_geom_webmercator': '0101000020110F00007BFC4E590BEA5FC156AE9FC6F0855241',
#    'objectid': 5470560,
#    'service_request_id': 18427025,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:58:06Z',
#    'updated_datetime': '2025-10-14T23:03:11Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '514 DICKINSON ST',
#    'zipcode': '19147',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_d3a05d1d8f6f0c35b17ddf10fba7563b',
#    'lat': 39.92980592,
#    'lon': -75.15418312},
#   {'cartodb_id': 134513,
#    'the_geom': '0101000020E6100000B8613C75FBC752C0857B0ED2EEFD4340',
#    'the_geom_webmercator': '0101000020110F00000384A978D7E65FC1B6FA71F29A8D5241',
#    'objectid': 5462447,
#    'service_request_id': 18270372,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:06:13Z',
#    'updated_datetime': '2025-10-10T11:25:40Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T11:25:00Z',
#    'address': '2537 FRANKFORD AVE',
#    'zipcode': '19125',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_04ed89f68d4bc0ea2bb643eeeefb112c',
#    'lat': 39.98385072,
#    'lon': -75.12472278},
#   {'cartodb_id': 349078,
#    'the_geom': '0101000020E6100000F1FFD84632CE52C00664F666E9F84340',
#    'the_geom_webmercator': '0101000020110F000027D61BA365F15FC134F64D920A885241',
#    'objectid': 5470753,
#    'service_request_id': 18427467,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:23:18Z',
#    'updated_datetime': '2025-10-14T23:28:27Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '5105 WARRINGTON AVE',
#    'zipcode': '19143',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_78d46b4b69881485421b30d9ec134893',
#    'lat': 39.94462287,
#    'lon': -75.22181865},
#   {'cartodb_id': 224659,
#    'the_geom': '0101000020E610000007D0EFFB37C052C0E257ACE122094440',
#    'the_geom_webmercator': '0101000020110F000062650B8CA7D95FC1FE7E2B01089A5241',
#    'objectid': 5470676,
#    'service_request_id': 18427280,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:12:53Z',
#    'updated_datetime': '2025-10-14T23:17:59Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '9555–9595   Academy Rd',
#    'zipcode': '19114',
#    'media_url': None,
#    'lat': 40.071377,
#    'lon': -75.003417},
#   {'cartodb_id': 300166,
#    'the_geom': '0101000020E610000057201F9933CC52C024DD859CADF44340',
#    'the_geom_webmercator': '0101000020110F0000BE2EB83202EE5FC10C5224415A835241',
#    'objectid': 5470639,
#    'service_request_id': 18427194,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:08:27Z',
#    'updated_datetime': '2025-10-14T23:13:34Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2500   Hartranft St',
#    'zipcode': None,
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_6409a4ddaa62494309eb4f9e8c06fcee',
#    'lat': 39.9115482,
#    'lon': -75.1906493},
#   {'cartodb_id': 183478,
#    'the_geom': '0101000020E6100000E79C22A38DCB52C02A4B73E5A2FD4340',
#    'the_geom_webmercator': '0101000020110F0000010DFF4BE8EC5FC116A2DFCA468D5241',
#    'objectid': 5470647,
#    'service_request_id': 18427210,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:09:10Z',
#    'updated_datetime': '2025-10-14T23:14:15Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2804 CECIL B MOORE AVE',
#    'zipcode': '19121',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_6949f8e9aed15ac9ab99b2b30569a688',
#    'lat': 39.9815337,
#    'lon': -75.18051985},
#   {'cartodb_id': 291831,
#    'the_geom': '0101000020E6100000446B459BE3CF52C03F70952710F24340',
#    'the_geom_webmercator': '0101000020110F00000C38FEB045F45FC1B77BEA1B75805241',
#    'objectid': 5470636,
#    'service_request_id': 18427186,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:08:06Z',
#    'updated_datetime': '2025-10-14T23:13:11Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '3100–3134   S 86th St',
#    'zipcode': '19153',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_d66d51b5ce48c5682ab65e18efb9680c',
#    'lat': 39.891118,
#    'lon': -75.248267},
#   {'cartodb_id': 378176,
#    'the_geom': '0101000020E6100000898EBE14A1CA52C05FF7593F8BFB4340',
#    'the_geom_webmercator': '0101000020110F0000F7BC797B56EB5FC1038FCB28F58A5241',
#    'objectid': 5470760,
#    'service_request_id': 18427479,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:24:27Z',
#    'updated_datetime': '2025-10-14T23:29:32Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1705 MOUNT VERNON ST',
#    'zipcode': '19130',
#    'media_url': None,
#    'lat': 39.965187,
#    'lon': -75.16608161},
#   {'cartodb_id': 608388,
#    'the_geom': '0101000020E6100000EC47D51E43C352C0C1D66C5355084440',
#    'the_geom_webmercator': '0101000020110F0000711E0DFDD2DE5FC1FFD161E123995241',
#    'objectid': 5470885,
#    'service_request_id': 18429227,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:22:52Z',
#    'updated_datetime': '2025-10-15T03:27:56Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2100 BENSON ST',
#    'zipcode': '19152',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_5f48f629812012a2c4d9ca82e37a0650',
#    'lat': 40.06510394,
#    'lon': -75.05097171},
#   {'cartodb_id': 535641,
#    'the_geom': '0101000020E610000046372885CCCD52C0C868EF1CA2FA4340',
#    'the_geom_webmercator': '0101000020110F0000788516CBB8F05FC1728812D5F2895241',
#    'objectid': 5470862,
#    'service_request_id': 18429170,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:19:29Z',
#    'updated_datetime': '2025-10-15T03:24:35Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '4720   Ludlow St',
#    'zipcode': None,
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_1348026d206b30ab79afab43ef46eb1d',
#    'lat': 39.9580723,
#    'lon': -75.21560792},
#   {'cartodb_id': 382497,
#    'the_geom': '0101000020E6100000A2746B5D6DCA52C0DACC07A71BF64340',
#    'the_geom_webmercator': '0101000020110F00007C8226A3FEEA5FC176581E96EF845241',
#    'objectid': 5470763,
#    'service_request_id': 18427486,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T23:24:50Z',
#    'updated_datetime': '2025-10-14T23:29:54Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '955 WINTON ST',
#    'zipcode': '19148',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_4c935e6fec2f08aad05c996d6f3efd3b',
#    'lat': 39.92271889,
#    'lon': -75.16292511},
#   {'cartodb_id': 500169,
#    'the_geom': '0101000020E6100000621F6A91A0CA52C0DC5AC5A41BFE4340',
#    'the_geom_webmercator': '0101000020110F0000280C669C55EB5FC1C43662A1CC8D5241',
#    'objectid': 5470828,
#    'service_request_id': 18429099,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:14:12Z',
#    'updated_datetime': '2025-10-15T03:19:18Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2029 N 20TH ST',
#    'zipcode': '19121',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_c1d745784fe521612117d73c8165f199',
#    'lat': 39.98521862,
#    'lon': -75.16605029},
#   {'cartodb_id': 885345,
#    'the_geom': '0101000020E6100000E6E976DE5DCB52C0FC7E159BB6074440',
#    'the_geom_webmercator': '0101000020110F000097595E2897EC5FC164B795BF73985241',
#    'objectid': 5470978,
#    'service_request_id': 18429498,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:39:54Z',
#    'updated_datetime': '2025-10-15T03:44:58Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '540 VERNON RD',
#    'zipcode': '19119',
#    'media_url': None,
#    'lat': 40.06026019,
#    'lon': -75.17760431},
#   {'cartodb_id': 724499,
#    'the_geom': '0101000020E610000076F154306DC952C008485F8059FF4340',
#    'the_geom_webmercator': '0101000020110F000073BF127F4BE95FC1D8F78FFB2C8F5241',
#    'objectid': 5470934,
#    'service_request_id': 18429369,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:32:05Z',
#    'updated_datetime': '2025-10-15T03:37:10Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2809 GERMANTOWN AVE',
#    'zipcode': '19133',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_fcebf6063b777a878b2ba9ddc906297f',
#    'lat': 39.99491887,
#    'lon': -75.14728936},
#   {'cartodb_id': 830977,
#    'the_geom': '0101000020E6100000FB4E41D626CB52C0FFEB1F7E6BFB4340',
#    'the_geom_webmercator': '0101000020110F0000899120AE39EC5FC1794BB7F8D18A5241',
#    'objectid': 5470922,
#    'service_request_id': 18429339,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:30:11Z',
#    'updated_datetime': '2025-10-15T03:35:16Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2133 SPRING GARDEN ST',
#    'zipcode': '19130',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_1f4a7d99d5e750c8309679560dbc7163',
#    'lat': 39.96421792,
#    'lon': -75.17424542},
#   {'cartodb_id': 670949,
#    'the_geom': '0101000020E610000053859C0423CB52C00A1E2F6F16F84340',
#    'the_geom_webmercator': '0101000020110F00007342803133EC5FC147D81DE020875241',
#    'objectid': 5470891,
#    'service_request_id': 18429240,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:23:36Z',
#    'updated_datetime': '2025-10-15T03:28:40Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1800 WASHINGTON AVE',
#    'zipcode': '19146',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_5e6261ab5c42abc3208fde6013f5575d',
#    'lat': 39.93818464,
#    'lon': -75.17401233},
#   {'cartodb_id': 719042,
#    'the_geom': '0101000020E6100000EC47D51E43C352C0C1D66C5355084440',
#    'the_geom_webmercator': '0101000020110F0000711E0DFDD2DE5FC1FFD161E123995241',
#    'objectid': 5470884,
#    'service_request_id': 18429226,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:22:47Z',
#    'updated_datetime': '2025-10-15T03:27:51Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2100 BENSON ST',
#    'zipcode': '19152',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_ac4ee1ab684f99eee232ff110e4fb0e1',
#    'lat': 40.06510394,
#    'lon': -75.05097171},
#   {'cartodb_id': 834653,
#    'the_geom': '0101000020E6100000BABACB9E39C852C0664C15B86D024440',
#    'the_geom_webmercator': '0101000020110F000090F2710F41E75FC1A93B76F496925241',
#    'objectid': 5470923,
#    'service_request_id': 18429344,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:30:33Z',
#    'updated_datetime': '2025-10-15T03:35:37Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '197 W WINGOHOCKING ST',
#    'zipcode': '19140',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_2045e3c50437707fd5abf4d9a2a294e5',
#    'lat': 40.01897336,
#    'lon': -75.12851686},
#   {'cartodb_id': 696230,
#    'the_geom': '0101000020E6100000779D2AA545CA52C05533D3FB18FE4340',
#    'the_geom_webmercator': '0101000020110F0000C058592BBBEA5FC1412C98AEC98D5241',
#    'objectid': 5470876,
#    'service_request_id': 18429207,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:21:33Z',
#    'updated_datetime': '2025-10-15T03:26:38Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1620 DIAMOND ST',
#    'zipcode': '19121',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_048ce8248777d524591b4ed66cf1470d',
#    'lat': 39.98513744,
#    'lon': -75.1605008},
#   {'cartodb_id': 738113,
#    'the_geom': '0101000020E6100000A33CF6E508D052C0893115352BFD4340',
#    'the_geom_webmercator': '0101000020110F0000F202020985F45FC18ECA8322C28C5241',
#    'objectid': 5470937,
#    'service_request_id': 18429380,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:32:41Z',
#    'updated_datetime': '2025-10-15T03:37:46Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '6506 LEBANON AVE',
#    'zipcode': '19151',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_37920c384781c816b8e3aeebb8cd0cdf',
#    'lat': 39.97788108,
#    'lon': -75.25054311},
#   {'cartodb_id': 858249,
#    'the_geom': '0101000020E61000006AF981AB3CCA52C047AF06280DF94340',
#    'the_geom_webmercator': '0101000020110F0000525E8BECABEA5FC169E5022E32885241',
#    'objectid': 5470931,
#    'service_request_id': 18429359,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:31:25Z',
#    'updated_datetime': '2025-10-15T03:36:31Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1101–1199   Cypress St',
#    'zipcode': '19107',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_702a232eb06a57dcd9522a921ffc5d24',
#    'lat': 39.945714,
#    'lon': -75.159953},
#   {'cartodb_id': 1012239,
#    'the_geom': '0101000020E6100000D8A6798E04CA52C0A6181626D3F54340',
#    'the_geom_webmercator': '0101000020110F00001656179C4CEA5FC11FEE7E4B9F845241',
#    'objectid': 5471085,
#    'service_request_id': 18429929,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T04:17:53Z',
#    'updated_datetime': '2025-10-15T04:22:59Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2230 S FAIRHILL ST',
#    'zipcode': '19148',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_2566a8b54628ddc4e910d4dd5b5f2190',
#    'lat': 39.92050625,
#    'lon': -75.15652811},
#   {'cartodb_id': 918320,
#    'the_geom': '0101000020E6100000EE42739D46CA52C01E6E8786C5F44340',
#    'the_geom_webmercator': '0101000020110F0000218015D1BCEA5FC172AAC4BB74835241',
#    'objectid': 5470986,
#    'service_request_id': 18429515,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:40:56Z',
#    'updated_datetime': '2025-10-15T03:46:01Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2926–2934   S Seventh St',
#    'zipcode': '19148',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_1f119d145503a632df8bfff39da6423a',
#    'lat': 39.912278,
#    'lon': -75.16056},
#   {'cartodb_id': 909587,
#    'the_geom': '0101000020E6100000C8B2D0A3FDC752C043407BFBD2FE4340',
#    'the_geom_webmercator': '0101000020110F00002526772DDBE65FC15E13F6DB978E5241',
#    'objectid': 5470985,
#    'service_request_id': 18429512,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:40:45Z',
#    'updated_datetime': '2025-10-15T03:45:49Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2702 C ST',
#    'zipcode': '19134',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_cff6f5d96baf9f58b3d4dbab6523b779',
#    'lat': 39.99081367,
#    'lon': -75.12485595},
#   {'cartodb_id': 923780,
#    'the_geom': '0101000020E6100000E7D51128B7CE52C07B0438CE3EF44340',
#    'the_geom_webmercator': '0101000020110F00000B8FC85847F25FC1C9EB5491DF825241',
#    'objectid': 5470988,
#    'service_request_id': 18429520,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:41:21Z',
#    'updated_datetime': '2025-10-15T03:46:26Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '7200R LINDBERGH BLVD',
#    'zipcode': '19153',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_f75b4613bee88400ebb13f1df258e977',
#    'lat': 39.90816667,
#    'lon': -75.22992899},
#   {'cartodb_id': 928292,
#    'the_geom': '0101000020E6100000BE6EFC6710CF52C044F35CFA81F64340',
#    'the_geom_webmercator': '0101000020110F0000C8C144F2DEF25FC174094AE860855241',
#    'objectid': 5471060,
#    'service_request_id': 18429713,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:53:39Z',
#    'updated_datetime': '2025-10-15T03:58:44Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2131 S DAGGETT ST',
#    'zipcode': '19142',
#    'media_url': None,
#    'lat': 39.92584161,
#    'lon': -75.23537635},
#   {'cartodb_id': 920261,
#    'the_geom': '0101000020E610000079BE95FCD2CA52C0E9CD5399DAF84340',
#    'the_geom_webmercator': '0101000020110F000041C08640ABEB5FC155BF372CFA875241',
#    'objectid': 5470987,
#    'service_request_id': 18429517,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:41:06Z',
#    'updated_datetime': '2025-10-15T03:46:10Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1607 SOUTH ST',
#    'zipcode': '19146',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_84653ca619c6cb9829ba51a665f307f3',
#    'lat': 39.94417111,
#    'lon': -75.1691276},
#   {'cartodb_id': 982752,
#    'the_geom': '0101000020E61000005479062ED9C452C05593EC0419024440',
#    'the_geom_webmercator': '0101000020110F000010919CB884E15FC158017D0639925241',
#    'objectid': 5470941,
#    'service_request_id': 18429388,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T03:33:09Z',
#    'updated_datetime': '2025-10-15T03:38:13Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1859 HARRISON ST',
#    'zipcode': '19124',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_8a53600caf93516e52cce483512d0c90',
#    'lat': 40.01638853,
#    'lon': -75.0757556},
#   {'cartodb_id': 1354644,
#    'the_geom': '0101000020E61000006938C89ABFC952C0DBD01E1F6E024440',
#    'the_geom_webmercator': '0101000020110F00008507EA7CD7E95FC17CAABA6697925241',
#    'objectid': 5462610,
#    'service_request_id': 18270611,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:28:07Z',
#    'updated_datetime': '2025-10-08T15:06:11Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': '4301 N 16TH ST',
#    'zipcode': '19140',
#    'media_url': None,
#    'lat': 40.01898564,
#    'lon': -75.15231962},
#   {'cartodb_id': 1297877,
#    'the_geom': '0101000020E61000005542B4E41ED052C0CB9C6D5DA1FC4340',
#    'the_geom_webmercator': '0101000020110F0000B8E56365AAF45FC16173915D298C5241',
#    'objectid': 5462626,
#    'service_request_id': 18270636,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:30:26Z',
#    'updated_datetime': '2025-10-14T10:55:38Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-14T10:47:45Z',
#    'address': '700 N 66TH ST',
#    'zipcode': '19151',
#    'media_url': None,
#    'lat': 39.97367447,
#    'lon': -75.25188558},
#   {'cartodb_id': 1298143,
#    'the_geom': '0101000020E610000041EC087004CC52C0B370FCAD0DFD4340',
#    'the_geom_webmercator': '0101000020110F000067E35D17B2ED5FC16685A468A18C5241',
#    'objectid': 5462628,
#    'service_request_id': 18270639,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:30:45Z',
#    'updated_datetime': '2025-10-10T10:48:15Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T10:43:15Z',
#    'address': '3163 W THOMPSON ST',
#    'zipcode': '19121',
#    'media_url': None,
#    'lat': 39.97697997,
#    'lon': -75.18777085},
#   {'cartodb_id': 1298753,
#    'the_geom': '0101000020E61000009DEB6648E2CD52C0BBED8FFE85FB4340',
#    'the_geom_webmercator': '0101000020110F0000337B68C2DDF05FC12C979C56EF8A5241',
#    'objectid': 5462629,
#    'service_request_id': 18270642,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:31:00Z',
#    'updated_datetime': '2025-10-14T10:56:57Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-14T10:51:36Z',
#    'address': '4808 ASPEN ST',
#    'zipcode': '19139',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_623221544764522d01eb42c1df4982a3',
#    'lat': 39.96502668,
#    'lon': -75.21693621},
#   {'cartodb_id': 1182382,
#    'the_geom': '0101000020E61000008A70118F06CA52C00E357AE7D7F54340',
#    'the_geom_webmercator': '0101000020110F00001425C80250EA5FC1AD2EA18FA4845241',
#    'objectid': 5471100,
#    'service_request_id': 18429951,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-15T04:19:58Z',
#    'updated_datetime': '2025-10-15T04:25:04Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '538 TREE ST',
#    'zipcode': '19148',
#    'media_url': None,
#    'lat': 39.92065137,
#    'lon': -75.15665032},
#   {'cartodb_id': 1302883,
#    'the_geom': '0101000020E610000041EC087004CC52C0B370FCAD0DFD4340',
#    'the_geom_webmercator': '0101000020110F000067E35D17B2ED5FC16685A468A18C5241',
#    'objectid': 5462631,
#    'service_request_id': 18270644,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:31:11Z',
#    'updated_datetime': '2025-10-10T10:48:17Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T10:43:17Z',
#    'address': '3163 W THOMPSON ST',
#    'zipcode': '19121',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_47d48d7560a9c0fe57ba67e20d7a082a',
#    'lat': 39.97697997,
#    'lon': -75.18777085},
#   {'cartodb_id': 1480762,
#    'the_geom': '0101000020E61000007188CB6BA2CA52C00B3D10CA60F74340',
#    'the_geom_webmercator': '0101000020110F0000E6802EC258EB5FC1D51BCFAD57865241',
#    'objectid': 5462791,
#    'service_request_id': 18270860,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:50:24Z',
#    'updated_datetime': '2025-10-10T10:49:05Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T10:46:59Z',
#    'address': '1306 REED ST',
#    'zipcode': '19147',
#    'media_url': None,
#    'lat': 39.93264128,
#    'lon': -75.1661634},
#   {'cartodb_id': 1381218,
#    'the_geom': '0101000020E6100000CBE835736FCA52C0151EAF849D044440',
#    'the_geom_webmercator': '0101000020110F00006D0ED92D02EB5FC146BD50D803955241',
#    'objectid': 5462620,
#    'service_request_id': 18270623,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:29:15Z',
#    'updated_datetime': '2025-10-08T16:04:52Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': 'E BRINGHURST ST & RUFE ST',
#    'zipcode': '19144',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_87af33134e8c19e00ebad35f8a56910d',
#    'lat': 40.03605708,
#    'lon': -75.16305237},
#   {'cartodb_id': 1472878,
#    'the_geom': '0101000020E610000046B4C9EAD6CF52C0DB5FEC11FAFB4340',
#    'the_geom_webmercator': '0101000020110F000095091E2330F45FC1BB1A84F76F8B5241',
#    'objectid': 5462789,
#    'service_request_id': 18270858,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:50:12Z',
#    'updated_datetime': '2025-10-15T03:04:04Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-14T10:48:57Z',
#    'address': '331 N 64TH ST',
#    'zipcode': '19139',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_3639b13c25d2f3b8dbd4049e8f57d7ae',
#    'lat': 39.96856903,
#    'lon': -75.2474925},
#   {'cartodb_id': 1363634,
#    'the_geom': '0101000020E6100000996363989ACB52C02CBBE87C9EFD4340',
#    'the_geom_webmercator': '0101000020110F00005833AF4EFEEC5FC101CA04E8418D5241',
#    'objectid': 5462616,
#    'service_request_id': 18270618,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:28:45Z',
#    'updated_datetime': '2025-10-10T10:49:04Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T10:46:57Z',
#    'address': '1647 N DOVER ST',
#    'zipcode': '19121',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_15a80e1abac5a87dd3c75aa6a494b396',
#    'lat': 39.98139917,
#    'lon': -75.18131075},
#   {'cartodb_id': 1837958,
#    'the_geom': '0101000020E61000005E69B7F9DFC252C0A8A5FD627C044440',
#    'the_geom_webmercator': '0101000020110F00002DA6AB942ADE5FC1384FE817DF945241',
#    'objectid': 5463048,
#    'service_request_id': 18271221,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T02:13:55Z',
#    'updated_datetime': '2025-10-14T11:46:56Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-14T11:44:54Z',
#    'address': '7106 FRANKFORD AVE',
#    'zipcode': '19135',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_ffabc937ae41bdf108433cc0d4e23b92',
#    'lat': 40.03504598,
#    'lon': -75.04492038},
#   {'cartodb_id': 1727603,
#    'the_geom': '0101000020E61000002F2569E0C6C852C0157C6E7B7AFD4340',
#    'the_geom_webmercator': '0101000020110F0000204096FF30E85FC1C5D89FFF198D5241',
#    'objectid': 5462978,
#    'service_request_id': 18271127,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T01:20:30Z',
#    'updated_datetime': '2025-10-10T11:26:36Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T11:24:40Z',
#    'address': '1941 N 2ND ST',
#    'zipcode': '19122',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_7e868e5d7e1e3f23cff2a9aaa72a7df1',
#    'lat': 39.98030036,
#    'lon': -75.13713846},
#   {'cartodb_id': 1832631,
#    'the_geom': '0101000020E6100000AD716F9AD4CA52C0A2B7B92577FB4340',
#    'the_geom_webmercator': '0101000020110F0000022F7EFFADEB5FC11D11DCE2DE8A5241',
#    'objectid': 5463043,
#    'service_request_id': 18271216,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T02:13:29Z',
#    'updated_datetime': '2025-10-14T10:59:16Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-14T10:47:50Z',
#    'address': '540 N 19TH ST',
#    'zipcode': '19130',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_e9e8b8e934e6a7ac621efa61c6e587a8',
#    'lat': 39.96457359,
#    'lon': -75.16922627},
#   {'cartodb_id': 1833683,
#    'the_geom': '0101000020E61000005C17BEC598C952C0C3DF04B115FF4340',
#    'the_geom_webmercator': '0101000020110F0000FCE00E8795E95FC1C7EF44CFE18E5241',
#    'objectid': 5463464,
#    'service_request_id': 18271763,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T14:41:11Z',
#    'updated_datetime': '2025-10-10T11:26:28Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T11:23:46Z',
#    'address': 'N JESSUP ST & W OAKDALE ST',
#    'zipcode': '19133',
#    'media_url': None,
#    'lat': 39.99284947,
#    'lon': -75.14994949},
#   {'cartodb_id': 1731631,
#    'the_geom': '0101000020E610000063CF156386C752C093B370C172044440',
#    'the_geom_webmercator': '0101000020110F0000646C589D10E65FC190DEFE68D4945241',
#    'objectid': 5462980,
#    'service_request_id': 18271129,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T01:20:41Z',
#    'updated_datetime': '2025-10-10T12:26:02Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': 'B ST & E OLNEY AVE',
#    'zipcode': '19120',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_6474e639ec9b3d3d75f635f31000906a',
#    'lat': 40.03475206,
#    'lon': -75.11757733},
#   {'cartodb_id': 1811002,
#    'the_geom': '0101000020E6100000F473964F51CF52C0FEBB68A1D3FC4340',
#    'the_geom_webmercator': '0101000020110F0000CA3B8A314DF35FC16CAFBD12618C5241',
#    'objectid': 5463446,
#    'service_request_id': 18271743,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T14:36:03Z',
#    'updated_datetime': '2025-10-09T11:10:17Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-09T11:06:13Z',
#    'address': '1528 N REDFIELD ST',
#    'zipcode': '19151',
#    'media_url': None,
#    'lat': 39.97520845,
#    'lon': -75.23933782},
#   {'cartodb_id': 1684565,
#    'the_geom': '0101000020E61000000A16F28907CF52C04ADCCC0201F94340',
#    'the_geom_webmercator': '0101000020110F0000976260E2CFF25FC17CB69CB924885241',
#    'objectid': 5462827,
#    'service_request_id': 18270910,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T01:00:34Z',
#    'updated_datetime': '2025-10-14T10:55:39Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-14T10:47:47Z',
#    'address': '1014 S 56TH ST',
#    'zipcode': '19143',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_246d09fd1848b7e16e81c068dc94c87f',
#    'lat': 39.94534335,
#    'lon': -75.23483513},
#   {'cartodb_id': 1846076,
#    'the_geom': '0101000020E6100000DBBEA67238C752C0F3DB4A19DEFF4340',
#    'the_geom_webmercator': '0101000020110F000091F4203A8CE55FC16BEF06FCBF8F5241',
#    'objectid': 5463080,
#    'service_request_id': 18271268,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T02:18:07Z',
#    'updated_datetime': '2025-10-09T19:04:31Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': '3334 H ST',
#    'zipcode': '19134',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_e3bfebbe23dbc95dcd288442218fc83d',
#    'lat': 39.99896542,
#    'lon': -75.1128203},
#   {'cartodb_id': 1844026,
#    'the_geom': '0101000020E61000007C9161BC50CA52C04AC61C94D3044440',
#    'the_geom_webmercator': '0101000020110F00000E730A02CEEA5FC157AB25D03F955241',
#    'objectid': 5463378,
#    'service_request_id': 18271661,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T14:15:47Z',
#    'updated_datetime': '2025-10-08T14:45:08Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': '501 E BRINGHURST ST',
#    'zipcode': '19144',
#    'media_url': None,
#    'lat': 40.03770687,
#    'lon': -75.16117773},
#   {'cartodb_id': 1893336,
#    'the_geom': '0101000020E61000006A5C98327DC852C0B895317876004440',
#    'the_geom_webmercator': '0101000020110F00002828E5D8B3E75FC10B3220EB68905241',
#    'objectid': 5463611,
#    'service_request_id': 18271935,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T15:22:51Z',
#    'updated_datetime': '2025-10-10T11:25:55Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-10T11:25:34Z',
#    'address': '208 W TIOGA ST',
#    'zipcode': '19140',
#    'media_url': None,
#    'lat': 40.0036154,
#    'lon': -75.13264146},
#   {'cartodb_id': 1862617,
#    'the_geom': '0101000020E6100000D33D5E87E0BE52C0ECB3D5843C084440',
#    'the_geom_webmercator': '0101000020110F00007A24512760D75FC1C424E85908995241',
#    'objectid': 5463163,
#    'service_request_id': 18271398,
#    'subject': 'Illegal Dumping',
#    'status': 'Closed',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T12:20:40Z',
#    'updated_datetime': '2025-10-09T11:11:16Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': '2025-10-09T11:08:12Z',
#    'address': '10034 HEGERMAN ST',
#    'zipcode': '19114',
#    'media_url': None,
#    'lat': 40.06434689,
#    'lon': -74.98245415},
#   {'cartodb_id': 1857518,
#    'the_geom': '0101000020E6100000DA46353E57C752C0F439C717A6024440',
#    'the_geom_webmercator': '0101000020110F000006A92489C0E55FC130B34879D5925241',
#    'objectid': 5463115,
#    'service_request_id': 18271318,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T02:22:58Z',
#    'updated_datetime': '2025-10-09T13:41:56Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': '4710 RORER ST',
#    'zipcode': '19120',
#    'media_url': None,
#    'lat': 40.02069375,
#    'lon': -75.11469989},
# ...
#    'closed_datetime': None,
#    'address': '5045 TULIP ST',
#    'zipcode': '19124',
#    'media_url': None,
#    'lat': 40.01162913,
#    'lon': -75.07147339},
#   {'cartodb_id': 5026293,
#    'the_geom': '0101000020E6100000080F9A5F9AC652C04D21CC7F8DFE4340',
#    'the_geom_webmercator': '0101000020110F0000E1DDC5B87FE45FC1FE2205D64A8E5241',
#    'objectid': 5470389,
#    'service_request_id': 18426100,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T21:19:44Z',
#    'updated_datetime': '2025-10-14T21:42:25Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '3295 CHATHAM ST',
#    'zipcode': '19134',
#    'media_url': None,
#    'lat': 39.98869321,
#    'lon': -75.10317221},
#   {'cartodb_id': 5027597,
#    'the_geom': '0101000020E61000008FA7B3CD42C852C076E8B10780014440',
#    'the_geom_webmercator': '0101000020110F0000A808B2A850E75FC1ED2CBB5F8F915241',
#    'objectid': 5462433,
#    'service_request_id': 18270350,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-08T00:04:00Z',
#    'updated_datetime': '2025-10-08T12:43:14Z',
#    'expected_datetime': '2025-10-15T00:00:00Z',
#    'closed_datetime': None,
#    'address': '151 W LUZERNE ST',
#    'zipcode': '19140',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_16add5a3e035701c159ff81b82f423bf',
#    'lat': 40.01171967,
#    'lon': -75.12907736},
#   {'cartodb_id': 5144634,
#    'the_geom': '0101000020E61000004F64433620C852C0D9C2855F89054440',
#    'the_geom_webmercator': '0101000020110F00002D8DD7E615E75FC1EA41367C09965241',
#    'objectid': 5470404,
#    'service_request_id': 18426256,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T21:36:40Z',
#    'updated_datetime': '2025-10-14T22:03:52Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '326 FERN ST',
#    'zipcode': '19120',
#    'media_url': None,
#    'lat': 40.0432548,
#    'lon': -75.12696606},
#   {'cartodb_id': 5061473,
#    'the_geom': '0101000020E61000002E11EFAE89C952C04BC4080075084440',
#    'the_geom_webmercator': '0101000020110F0000CE58B0E57BE95FC1E52DE80747995241',
#    'objectid': 5470294,
#    'service_request_id': 18425670,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T20:27:47Z',
#    'updated_datetime': '2025-10-14T21:05:49Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1950 ASHLEY RD',
#    'zipcode': '19138',
#    'media_url': None,
#    'lat': 40.06607056,
#    'lon': -75.14902852},
#   {'cartodb_id': 5147202,
#    'the_geom': None,
#    'the_geom_webmercator': None,
#    'objectid': 5470414,
#    'service_request_id': 18426341,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T21:47:35Z',
#    'updated_datetime': '2025-10-14T21:52:45Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': 'Lena & Chelten ave',
#    'zipcode': '19144',
#    'media_url': None,
#    'lat': None,
#    'lon': None},
#   {'cartodb_id': 5145489,
#    'the_geom': '0101000020E6100000F400C734FFCA52C03E1F3CF6B6044440',
#    'the_geom_webmercator': '0101000020110F00003428035DF6EB5FC1F59BA21120955241',
#    'objectid': 5470408,
#    'service_request_id': 18426286,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T21:39:45Z',
#    'updated_datetime': '2025-10-14T22:03:45Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': 'E ARMAT ST & LENA ST',
#    'zipcode': '19144',
#    'media_url': None,
#    'lat': 40.03683355,
#    'lon': -75.17182655},
#   {'cartodb_id': 5162995,
#    'the_geom': '0101000020E6100000759B311EF0C752C0531756D185FC4340',
#    'the_geom_webmercator': '0101000020110F00000D958D35C4E65FC1EE7018D60A8C5241',
#    'objectid': 5470457,
#    'service_request_id': 18426786,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:44:49Z',
#    'updated_datetime': '2025-10-14T22:49:55Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '801 ARAMINGO AVE',
#    'zipcode': '19125',
#    'media_url': None,
#    'lat': 39.97283379,
#    'lon': -75.12403064},
#   {'cartodb_id': 5155983,
#    'the_geom': '0101000020E61000002F71D375F6CE52C0520F66FFBBFA4340',
#    'the_geom_webmercator': '0101000020110F00009027E4DFB2F25FC1303241830F8A5241',
#    'objectid': 5470441,
#    'service_request_id': 18426584,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:20:45Z',
#    'updated_datetime': '2025-10-14T22:45:23Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '5617 SANSOM ST',
#    'zipcode': '19139',
#    'media_url': None,
#    'lat': 39.95886223,
#    'lon': -75.23379274},
#   {'cartodb_id': 5169548,
#    'the_geom': '0101000020E61000002FD516E8A4C652C04EAECED666004440',
#    'the_geom_webmercator': '0101000020110F00000432079D91E45FC13F57A39657905241',
#    'objectid': 5470461,
#    'service_request_id': 18426796,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:45:21Z',
#    'updated_datetime': '2025-10-14T22:50:28Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '3700   L St',
#    'zipcode': None,
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_57fcc97bac5e3ee97a7a3a412ff2acdf',
#    'lat': 40.0031384,
#    'lon': -75.1038151},
#   {'cartodb_id': 5169491,
#    'the_geom': '0101000020E610000017EE540D27CA52C0BFDC99C847F54340',
#    'the_geom_webmercator': '0101000020110F0000288D303487EA5FC15F6AAAF704845241',
#    'objectid': 5470460,
#    'service_request_id': 18426793,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:45:09Z',
#    'updated_datetime': '2025-10-14T22:50:15Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2610 S MARSHALL ST',
#    'zipcode': '19148',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_79434d10ec6394584e2457f64bc422e4',
#    'lat': 39.91625316,
#    'lon': -75.15863355},
#   {'cartodb_id': 5223262,
#    'the_geom': '0101000020E6100000884CA775C2C952C0B59BBC5AFCF64340',
#    'the_geom_webmercator': '0101000020110F0000B16F5F56DCE95FC1F327D070E8855241',
#    'objectid': 5470480,
#    'service_request_id': 18426825,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:47:35Z',
#    'updated_datetime': '2025-10-14T22:52:41Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '414 DICKINSON ST',
#    'zipcode': '19147',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_418827f3e1b41a0497139cde30e0dc3e',
#    'lat': 39.92957625,
#    'lon': -75.15249387},
#   {'cartodb_id': 5182360,
#    'the_geom': '0101000020E61000001ABE77309AC252C0B8C25100E6034440',
#    'the_geom_webmercator': '0101000020110F00003671BF0AB4DD5FC1BB379A4838945241',
#    'objectid': 5470465,
#    'service_request_id': 18426803,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:45:43Z',
#    'updated_datetime': '2025-10-14T22:50:49Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '4439 PRINCETON AVE',
#    'zipcode': '19135',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_60d04d21647270730bc40a625e5663d6',
#    'lat': 40.03045658,
#    'lon': -75.04066097},
#   {'cartodb_id': 5173356,
#    'the_geom': '0101000020E61000002FD516E8A4C652C04EAECED666004440',
#    'the_geom_webmercator': '0101000020110F00000432079D91E45FC13F57A39657905241',
#    'objectid': 5470463,
#    'service_request_id': 18426800,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:45:32Z',
#    'updated_datetime': '2025-10-14T22:50:39Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '3700   L St',
#    'zipcode': None,
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_0de73cb24e91ea6fa84e18d588e45b47',
#    'lat': 40.0031384,
#    'lon': -75.1038151},
#   {'cartodb_id': 5273577,
#    'the_geom': '0101000020E6100000086422C187C852C0220C17A6A5FD4340',
#    'the_geom_webmercator': '0101000020110F0000620D6EC7C5E75FC1AE7FE2D7498D5241',
#    'objectid': 5470516,
#    'service_request_id': 18426903,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:51:49Z',
#    'updated_datetime': '2025-10-14T22:56:54Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '104 DIAMOND ST',
#    'zipcode': '19122',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_9858dfaed53b55c339fc5446c5ab805e',
#    'lat': 39.9816177,
#    'lon': -75.13328579},
#   {'cartodb_id': 5280136,
#    'the_geom': '0101000020E6100000393F448001CA52C088A662A513F84340',
#    'the_geom_webmercator': '0101000020110F0000AA5D6E6B47EA5FC1ACBE74C91D875241',
#    'objectid': 5470517,
#    'service_request_id': 18426905,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:51:54Z',
#    'updated_datetime': '2025-10-14T22:56:59Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '909 S 8TH ST',
#    'zipcode': '19147',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_69fb4443d46beb928c196c3e6bfda3e1',
#    'lat': 39.93809955,
#    'lon': -75.15634162},
#   {'cartodb_id': 5369127,
#    'the_geom': '0101000020E610000030105056D6CA52C016F3B0A66B054440',
#    'the_geom_webmercator': '0101000020110F00003C9F76F1B0EB5FC1C4502383E8955241',
#    'objectid': 5470495,
#    'service_request_id': 18426848,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:48:57Z',
#    'updated_datetime': '2025-10-14T22:54:03Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '5701   Magnolia St',
#    'zipcode': None,
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_5bf26ac6782ea6f1986cb07fc9ae506b',
#    'lat': 40.04234775,
#    'lon': -75.1693321},
#   {'cartodb_id': 5284234,
#    'the_geom': '0101000020E6100000E36C3A02B8CA52C0295E656D53F64340',
#    'the_geom_webmercator': '0101000020110F0000A76F626D7DEB5FC138A49C5A2D855241',
#    'objectid': 5470524,
#    'service_request_id': 18426933,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:53:16Z',
#    'updated_datetime': '2025-10-14T22:58:22Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '2027–2099   S 13th St',
#    'zipcode': '19148',
#    'media_url': None,
#    'lat': 39.924421,
#    'lon': -75.167481},
#   {'cartodb_id': 5286031,
#    'the_geom': '0101000020E610000053859C0423CB52C00A1E2F6F16F84340',
#    'the_geom_webmercator': '0101000020110F00007342803133EC5FC147D81DE020875241',
#    'objectid': 5470530,
#    'service_request_id': 18426945,
#    'subject': 'Illegal Dumping',
#    'status': 'Open',
#    'status_notes': None,
#    'service_name': 'Illegal Dumping',
#    'service_code': 'SR-ST02',
#    'agency_responsible': 'Streets Department',
#    'service_notice': '5 Business Days',
#    'requested_datetime': '2025-10-14T22:53:50Z',
#    'updated_datetime': '2025-10-14T22:58:55Z',
#    'expected_datetime': '2025-10-22T00:00:00Z',
#    'closed_datetime': None,
#    'address': '1800 WASHINGTON AVE',
#    'zipcode': '19146',
#    'media_url': 'https://d17aqltn7cihbm.cloudfront.net/uploads/large_93dc132cf395dc4eaa4407fd4fc288fe',
#    'lat': 39.93818464,
#    'lon': -75.17401233}],
#  'time': 0.475,
#  'fields': {'cartodb_id': {'type': 'number', 'pgtype': 'int8'},
#   'the_geom': {'type': 'geometry',
#    'wkbtype': 'Unknown',
#    'dims': 2,
#    'srid': 4326},
#   'the_geom_webmercator': {'type': 'geometry',
#    'wkbtype': 'Unknown',
#    'dims': 2,
#    'srid': 3857},
#   'objectid': {'type': 'number', 'pgtype': 'numeric'},
#   'service_request_id': {'type': 'number', 'pgtype': 'numeric'},
#   'subject': {'type': 'string', 'pgtype': 'text'},
#   'status': {'type': 'string', 'pgtype': 'text'},
#   'status_notes': {'type': 'string', 'pgtype': 'text'},
#   'service_name': {'type': 'string', 'pgtype': 'text'},
#   'service_code': {'type': 'string', 'pgtype': 'text'},
#   'agency_responsible': {'type': 'string', 'pgtype': 'text'},
#   'service_notice': {'type': 'string', 'pgtype': 'text'},
#   'requested_datetime': {'type': 'date', 'pgtype': 'timestamptz'},
#   'updated_datetime': {'type': 'date', 'pgtype': 'timestamptz'},
#   'expected_datetime': {'type': 'date', 'pgtype': 'timestamptz'},
#   'closed_datetime': {'type': 'date', 'pgtype': 'timestamptz'},
#   'address': {'type': 'string', 'pgtype': 'text'},
#   'zipcode': {'type': 'string', 'pgtype': 'text'},
#   'media_url': {'type': 'string', 'pgtype': 'text'},
#   'lat': {'type': 'number', 'pgtype': 'numeric'},
#   'lon': {'type': 'number', 'pgtype': 'numeric'}},
#  'total_rows': 418}
